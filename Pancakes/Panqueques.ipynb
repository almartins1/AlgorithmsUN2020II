# %% [markdown]
# <h1><b><center> LAB 8 | Pancakes With A Problem!

# %% [markdown]
# <h2> Referencias: </h2>
#
# Diapositivas: https://drive.google.com/file/d/131Qlmy_JcV9Wpl6gZnIf2ahXtG01Zccy/view
#
# Breadth First Search or BFS for a Graph https://www.geeksforgeeks.org/breadth-first-search-or-bfs-for-a-graph/
#
# Graph visualization using Python https://www.youtube.com/watch?v=SpDI6-FvtJY
#
# nikhilkumarsingh / PyDot-Examples https://github.com/nikhilkumarsingh/PyDot-Examples/blob/master/Directory_Structure_Plotter.ipynb
#
# pydot https://pypi.org/project/pydot/
#
# Graphviz https://www.graphviz.org/
#
# NetworkX https://networkx.github.io/

# %%
import pydot
from collections import defaultdict 
from IPython.display import Image, display

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %% [markdown]
# <h2><b> 1. Modify the PancakesTrees.ipynb code in your own to plot the Pancake Network and calculate Pn for smal n‘s.

# %%
#Funcion para hallar la distancia de cada nodo en la red de panqueques
def a(key, listo, distanci, nums):
        if(listo[key]):
           distanci[key] += 1 #Aumenta la distancia entre la permutacion y el nodo organizado
           for i in listo[key]:
                a(i, listo, distanci, nums)
        else:
            return(distanci)

#Funcion para hallar el Pn 
def xd(lista):
    dist={}  #Diccionario que contiene las distancias de cada nodo
    for x in lista:
        dist[x]=0
        if lista[x]:
            dist[x] += 1
    nums=[]
    ad = {}
    for x in lista:
        for y in lista[x]:
            ad = a(y, lista, dist, nums)
    all_values = ad.values()
    try:
        print(max(all_values))
    except:
        print("0")


    return 0

# %%
def ModifiedBFSRed(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        #Grafo no dirigido ya que estamos haciendo la red
        #Lo ponemos estricto para que solo halla un camino entre cada nodo
        G = pydot.Dot(graph_type="graph", strict=True)  
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
            # Dequeue a vertex from queue 
            #print("queue", queue)
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                #print("s",s)
                #print("d",d)
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                    node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
                else:
                    edge = pydot.Edge(lstr(s),lstr(d)) #Para completar la red
                    G.add_edge(edge)
        Pn = 0
        dist = {}       
        #Para calcular Pn
        xd(graph)
                                           
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %% [markdown]
# <h2><b> n = 1

# %%
p = [1]
print("El Pn generado es: ")
ModifiedBFSRed(p)
# Out:
# El Pn generado es:
# 0

# %% [markdown]
# <h2><b> n = 2

# %%
p = [2,1]
print("El Pn generado es: ")
ModifiedBFSRed(p)
# Out:
# El Pn generado es:
# 1

# %% [markdown]
# <h2><b> n = 3

# %%
p = [1,3,2]
print("El Pn generado es: ")
ModifiedBFSRed(p)
# Out:
# El Pn generado es:
# 3

# %% [markdown]
# <h2><b> n = 4

# %%
p = [2,4,1,3]
print("El Pn generado es: ")
ModifiedBFSRed(p)
# Out:
# El Pn generado es:
# 4

# %% [markdown]
# <h2><b> n = 5

# %%
p = [1,3,5,2,4]
print("El Pn generado es: ")
ModifiedBFSRed(p)
# Out:
# El Pn generado es:
# 5

# %% [markdown]
# <h2><b> 2. Modify the PancakesTrees.ipynb code leaving only the necessary code and data structures required to calculate the Pn and run the code for at least one night (8 hours) starting with n=5. What is the largest Pn calculated? (Save the results in drive to avoid losing them)

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        #Grafo no dirigido ya que estamos haciendo la red
        #Lo ponemos estricto para que solo halla un camino entre cada nodo
        #G = pydot.Dot(graph_type="graph", strict=True)  
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
            # Dequeue a vertex from queue 
            #print("queue", queue)
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            #node = pydot.Node(lstr(s))
            #G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 

        Pn = 0
        dist = {}       
        #Para calcular Pn
        xd(graph)

# %% [markdown]
# <h2><b> n = 5

# %%
p = [5,4,3,2,1]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:
# 5

# %% [markdown]
# <h2><b> n = 6

# %%
p = [6,5,4,3,2,1]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:
# 7

# %% [markdown]
# <h2><b> n = 7

# %%
p = [7,6,5,4,3,2,1]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:
# 8

# %% [markdown]
# <h2><b> n = 8

# %%
p = [8,7,6,5,4,3,2,1]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:
# 9

# %% [markdown]
# <h2><b> n = 9

# %%
p = [9,8,7,6,5,4,3,2,1]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:
# 10

# %% [markdown]
# <h2><b> n = 10

# %%
p = [1,3,5,7,9,2,4,6,8,10]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:
# 11

# %% [markdown]
# <h2><b> n = 11

# %%
p = [1,3,5,7,9,11,2,4,6,8,10]
print("El Pn generado es: ")
ModifiedBFS(p)
# Out:
# El Pn generado es:

# %% [markdown]
# Después de del tiempo propuesto el algoritmo no alcanzo a calcular Pn con n = 11

# %%
p = [1,3,5,7,9,11,2,4,6,8,10,12]
print("El Pn generado es: ")
ModifiedBFS(p)

# %%
p = [1,3,5,7,9,11,13,2,4,6,8,10,12]
print("El Pn generado es: ")
ModifiedBFS(p)

# %% [markdown]
# <h2><b>3. Modify the PancakesTrees.ipynb code to plot the pancakes trees using two spatulas.

# %%
def ModifiedBFS2Spat(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1): 
                  for j in range(i+1):          #Agregamos un for mas para recojer todos los posibles flips
                    d=s[0:j]+s[j:i+2][::-1]+s[i+2:]  #Cambiamos el generador para hacer el flip en los lugar establecido
                    if (d != s) and not(lstr(d) in visited.keys()):
                    
                        if(d != sorted(d)):
                            node = pydot.Node(lstr(d))
                        else:
                            node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                        
                        G.add_node(node)
                        edge = pydot.Edge(lstr(s),lstr(d))
                        G.add_edge(edge)
                        graph[lstr(s)].append(lstr(d))
                        queue.append(d) 
                        visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %% [markdown]
# <h2><b> Ejemplo para n = 3 con 2 espatulas

# %%
p = [3,1,2]
ModifiedBFS2Spat(p)

# %% [markdown]
# <h2><b> Ejemplo para n = 4 con 2 espatulas

# %%
p = [3,1,2,4]
ModifiedBFS2Spat(p)
